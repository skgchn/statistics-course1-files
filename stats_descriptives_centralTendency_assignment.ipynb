# %% [markdown]
# # COURSE: Master statistics and machine learning: Intuition, Math, code
# ##### COURSE URL: udemy.com/course/statsml_x/?couponCode=202006
# ## SECTION: Descriptive statistics
# ### VIDEO: Computing central tendency
# #### TEACHER: Mike X Cohen, sincxpress.com

# %%
# import libraries
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

# %%
## median

# create a log-normal distribution
shift   = 0
stretch = .7
n       = 200
nbins   = 50

# generate data
data = stretch*np.random.randn(n) + shift
data = np.exp( data )
for x in range(20):
  for y in range(10):
    data = np.append(data, (max(data)+min(data))/2 + x*y)
print(data[-5:])




# and its histogram
y,x = np.histogram(data, nbins)
x = (x[:-1]+x[1:])/2

# compute mean and median
datamean = np.mean(data)
datamedian = np.median(data)
print('mean: {}'.format(datamean))
print('median: {}'.format(datamedian))


# plot data
fig,ax = plt.subplots(2,1,figsize=(12,16))
ax[0].plot(data,'.',color=[.5,.5,.5],label='Data')
ax[0].plot([1,n],[datamean,datamean],'r--',label='Mean')
ax[0].plot([1,n],[datamedian,datamedian],'b--',label='Median')
ax[0].legend()

ax[1].plot(x,y)
ax[1].plot([datamean,datamean],[0,max(y)],'r--')
ax[1].plot([datamedian,datamedian],[0,max(y)],'b--')
ax[1].set_title('Log-normal data histogram')
plt.show()
# Out:
# [248.34132086 267.34132086 286.34132086 305.34132086 324.34132086]
# mean: 58.285494867495885
# median: 3.2549746028116466
